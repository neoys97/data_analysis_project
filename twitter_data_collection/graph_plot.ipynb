# %%
result_by_date = {'McDonalds': {'2019-11-13': {'polarity': 0.06359,
   'top10_words_with_stopwords': [('be', 151),
    ('to', 75),
    ('the', 68),
    ('mcdonalds', 64),
    ('a', 62),
    ('i', 60),
    ('and', 48),
    ('not', 43),
    ('for', 37),
    ('in', 34)],
   'top10_words_without_stopwords': [("mcdonalds", 54),
    ("mcdonald" , 35),
    ("get" , 31),
    ("worker" , 17),
    ("pay" , 14),
    ("£" , 13),
    ("15" , 12),
    ("see" , 11),
    ("people" , 11),
    ("hour" , 11),],
   'top10_hashtags': [("#Jeopardy" , 1),
    ("#Yelp" , 1),
    ("#Frozen2" , 1),
    ("#ToyStory4" , 1),
    ("#illinois" , 1),
    ("#McStrike" , 1),
    ("#mcdonalds" , 1),
    ("#QuidProJoe" , 1),
    ("#brixton" , 1)]},
  '2019-11-14': {'polarity': 0.02405,
   'top10_words_with_stopwords': [("be" , 168),
    ("mcdonalds" , 111),
    ("a" , 82),
    ("the" , 70),
    ("to" , 67),
    ("i" , 65),
    ("not" , 51),
    ("and" , 49),
    ("in" , 44),
    ("get" , 40)],
   'top10_words_without_stopwords': [('mcdonalds', 94),
    ('mcdonald', 43),
    ('get', 39),
    ('worker', 33),
    ('pay', 29),
    ('go', 25),
    ('work', 23),
    ('people', 20),
    ('like', 17),
    ('15', 14)],
   'top10_hashtags': [('#McDonalds', 3),
    ('#ira', 1),
    ('#fact', 1),
    ('#mcdonalds', 1),
    ('#KingofRnB', 1),
    ('#chitag', 1),
    ('#30Seconds', 1),
    ('#justsaying', 1)]},
  '2019-11-15': {'polarity': 0.04236,
   'top10_words_with_stopwords': [('be', 145),
    ('the', 96),
    ('mcdonalds', 95),
    ('i', 94),
    ('to', 72),
    ('a', 66),
    ('and', 62),
    ('in', 42),
    ('not', 39),
    ('have', 34)],
   'top10_words_without_stopwords': [('mcdonalds', 95),
    ('mcdonald', 22),
    ('get', 22),
    ('go', 19),
    ('like', 14),
    ('order', 14),
    ('pay', 12),
    ('free', 11),
    ('eat', 11),
    ('see', 10)],
   'top10_hashtags': [('#McDonalds', 3),
    ('#PartTime', 1),
    ('#chiletrabojos', 1),
    ('#Nuggets', 1),
    ('#BoomerCulture', 1),
    ('#chicken', 1),
    ('#nuggets', 1),
    ('#Killjoys', 1),
    ('#VoteLabour', 1),
    ('#Hangry', 1)]}},
 'BurgerKing': {'2019-11-13': {'polarity': 0.00614,
   'top10_words_with_stopwords': [('be', 112),
    ('the', 87),
    ('i', 68),
    ('to', 52),
    ('a', 47),
    ('burger', 42),
    ('not', 40),
    ('and', 38),
    ('have', 33),
    ('do', 28)],
   'top10_words_without_stopwords': [('burger', 42),
    ('king', 23),
    ('get', 21),
    ('impossible', 20),
    ('whopper', 16),
    ('food', 16),
    ('new', 14),
    ('back', 12),
    ('make', 11),
    ('like', 11)],
   'top10_hashtags': [('#BurgerKing', 18),
    ('#burgerking', 4),
    ('#impossiblewhopper', 4),
    ('#McStrike', 3),
    ('#McDonalds', 3),
    ('#fastfoodglobal', 2),
    ('#ffwu', 2),
    ('#saarbruecken', 2),
    ('#efat', 2),
    ('#mcdonalds', 2)]},
  '2019-11-14': {'polarity': 0.02443,
   'top10_words_with_stopwords': [('be', 99),
    ('the', 85),
    ('i', 82),
    ('a', 58),
    ('to', 47),
    ('and', 40),
    ('not', 39),
    ('do', 38),
    ('burger', 36),
    ('have', 36)],
   'top10_words_without_stopwords': [('burger', 36),
    ('get', 24),
    ('whopper', 22),
    ('king', 18),
    ('food', 14),
    ('like', 13),
    ('go', 11),
    ('enjoy', 10),
    ('order', 10),
    ('vegan', 10)],
   'top10_hashtags': [('#BurgerKing', 6),
    ('#burgerking', 4),
    ('#DAY6GRAVITYinMNL', 2),
    ('#Day6', 2),
    ('#Day6shorts', 2),
    ('#youngk', 2),
    ('#sungjin', 2),
    ('#wonpil', 2),
    ('#jae', 2),
    ('#plantbased', 2)]},
  '2019-11-15': {'polarity': 0.00651,
   'top10_words_with_stopwords': [('be', 114),
    ('the', 88),
    ("i", 84),
    ('a', 60),
    ('not', 49),
    ("to", 47),
    ('and', 39),
    ('in', 37),
    ('do', 35),
    ('have', 31)],
   'top10_words_without_stopwords': [('burger', 24),
    ('get', 19),
    ('whopper', 18),
    ('impossible', 14),
    ('go', 12),
    ('sandwich', 12),
    ('thank', 11),
    ('see', 10),
    ('king', 10),
    ('one', 9)],
   'top10_hashtags': [('#impossiblewhopper', 2),
    ('#burgerking', 2),
    ('#fryguy', 1),
    ('#SonicMovie', 1),
    ('#1', 1),
    ('#Spayathon4PR', 1),
    ('#shoutout', 1),
    ('#thankyou', 1),
    ('#ImpossibleWhopper', 1),
    ('#BurgerKing', 1)]}}}
search_words = ["McDonalds", "BurgerKing"]

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import pandas as pd
import numpy as np

#Rebuilding the dictionary so it is like an Excel Sheet
list_of_dates = list(result_by_date[search_words[0]].keys())
list_of_groups = ['top10_words_with_stopwords',
                  'top10_words_without_stopwords',
                  'top10_hashtags']

graph_dict = {'Date': list_of_dates, 
              'Polarity_BK': [result_by_date["BurgerKing"][date]["polarity"] for date in list_of_dates],
              'Polarity_McD': [result_by_date["McDonalds"][date]["polarity"] for date in list_of_dates] }

#Converting the dictionary to a DataFrame

df_graph = pd.DataFrame.from_dict(graph_dict)

print(df_graph)

#Graphing using Matplotlib

ax = plt.gca()

df_graph.plot(kind='line',x='Date',y='Polarity_BK',ax=ax)
df_graph.plot(kind='line',x='Date',y='Polarity_McD', color='red',ax=ax)
# Out:
#          Date  Polarity_BK  Polarity_McD
# 0  2019-11-13      0.00614       0.06359
# 1  2019-11-14      0.02443       0.02405
# 2  2019-11-15      0.00651       0.04236

# %%
sub_titles = ["Top 10 Popular Words with stop words",
              "Top 10 Popular Words without stop words",
              "Top 10 Popular Hashtags"]
list_of_colors = ["tab:blue", "tab:purple", "tab:green"]
for word in search_words:
    fig, big_sbplts = plt.subplots(figsize=(20.0, 15.0) , nrows=3, ncols=1)
    fig.suptitle(word, size = 50, weight = "bold")
    for row, big_sbplt in enumerate(big_sbplts):
        big_sbplt.set_title(sub_titles[row] + "\n", fontsize=20, weight="bold", loc="left")
        big_sbplt.tick_params(labelcolor=(1.,1.,1., 0.0), top='off', bottom='off', left='off', right='off')
        big_sbplt._frameon = False
    
    index = 1
    for group in list_of_groups:
        for date in list_of_dates:
            y_objects = [x[0] for x in result_by_date[word][date][group]]
            y_values = np.arange(len(y_objects))
            x_values = [x[1] for x in result_by_date[word][date][group]]
            sbplt = fig.add_subplot(3, 3, index)
            index += 1 
            sbplt.barh(y_values, x_values, align="center", color=list_of_colors[index%len(list_of_colors)])
            sbplt.xaxis.set_major_locator(MaxNLocator(integer=True))
            sbplt.set_title(date)
            plt.sca(sbplt)
            plt.yticks(y_values, y_objects)
        
    fig.tight_layout(rect=[0, 0.03, 1, 0.95])
